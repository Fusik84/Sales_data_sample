# %% [markdown]
# <a href="https://colab.research.google.com/github/Fusik84/Sales_data_sample/blob/main/Sales_customers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
image = mpimg.imread ('R3.png')
plt.figure(figsize=(15,6))
plt.axis('off')
plt.imshow(image)

# %%
image = mpimg.imread ('R4.png')
plt.figure(figsize=(15,6))
plt.axis('off')
plt.imshow(image)

# %%
image = mpimg.imread ('R5.png')
plt.figure(figsize=(15,6))
plt.axis('off')
plt.imshow(image)

# %%
image = mpimg.imread ('R6.png')
plt.figure(figsize=(15,6))
plt.axis('off')
plt.imshow(image)

# %%
image = mpimg.imread ('R7.png')
plt.figure(figsize=(15,6))
plt.axis('off')
plt.imshow(image)

# %%
image = mpimg.imread ('R8.png')
plt.figure(figsize=(15,6))
plt.axis('off')
plt.imshow(image)

# %%
image = mpimg.imread ('R9.png')
plt.figure(figsize=(15,6))
plt.axis('off')
plt.imshow(image)

# %%
image = mpimg.imread ('R10.png')
plt.figure(figsize=(15,6))
plt.axis('off')
plt.imshow(image)

# %%
image = mpimg.imread ('R11.png')
plt.figure(figsize=(15,6))
plt.axis('off')
plt.imshow(image)
